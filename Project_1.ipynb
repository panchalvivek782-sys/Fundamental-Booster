# %%
print("Welcome to the interactive Personal Data \nCollector!")
n=input("\nPlease enter your name: ")
n2=abs(int(input("Please enter your age: ")))
n3=abs(float(input("Please enter your height in meters: ")))
n4=abs(int(input("Please enter your favourite number : ")))
print("\nThank you! Here is the information we \ncollected: ")
print(f"Name: {n} (Type: {type(n)},\nMemory Address: {id(n)})")
print(f"Age: {n2} (Type: {type(n2)},\nMemory Address: {id(n2)})")
print(f"Height: {n3} (Type: {type(n3)},\nMemory Address: {id(n3)})")
print(f"Favourite Number: {n4} (Type: {type(n4)},\nMemory Address: {id(n4)})")
print(f"\nYour birth year is approximately:\n{2026-n2} (based on your age of {n2})")
print("\nThank you for using the Personal Data\nCollector. Goodbye!")
# Out:
# Welcome to the interactive Personal Data
# Collector!
# Please enter your name:  Vivek
# Please enter your age:  17
# Please enter your height in meters:  1.83
# Please enter your favourite number :  67
# Thank you! Here is the information we
# collected:
# Name: Vivek (Type: <class 'str'>,
# Memory Address: 2275376861696)
# Age: 17 (Type: <class 'int'>,
# Memory Address: 140709069039016)
# Height: 1.83 (Type: <class 'float'>,
# Memory Address: 2275362948208)
# Favourite Number: 67 (Type: <class 'int'>,
# Memory Address: 140709069040616)
#
# Your birth year is approximately:
# 2009 (based on your age of 17)
#
# Thank you for using the Personal Data
# Collector. Goodbye!
